# %% [markdown]
# <a href="https://colab.research.google.com/github/umasai162/Heart-Disease-Analysis/blob/main/ZOMATO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/zomato.csv')

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
df.isnull()
# Out:
#          url  address   name  online_order  book_table   rate  votes  phone  \
# 0      False    False  False         False       False  False  False  False
# 1      False    False  False         False       False  False  False  False
# 2      False    False  False         False       False  False  False  False
# 3      False    False  False         False       False  False  False  False
# 4      False    False  False         False       False  False  False  False
# ...      ...      ...    ...           ...         ...    ...    ...    ...
# 51712  False    False  False         False       False  False  False  False
# 51713  False    False  False         False       False   True  False  False
# 51714  False    False  False         False       False   True  False   True
# 51715  False    False  False         False       False  False  False  False
# 51716  False    False  False         False       False  False  False  False
#
# ...

# %%
df['rest_type'].count()#total no of rest
# Out:
# np.int64(51490)

# %%
distribution = df['listed_in(type)'].value_counts()#Distribution by Delivery vs Dine-out
print(distribution)
# Out:
# listed_in(type)
# Delivery              25942
# Dine-out              17779
# Desserts               3593
# Cafes                  1723
# Drinks & nightlife     1101
# Buffet                  882
# Pubs and bars           697
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df=df.drop('url',axis=1)

# %%
df=df.fillna(0)

# %%
df.isnull().sum()
# Out:
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df.groupby(df['rest_type'],)['location'].count()
# Out:
# rest_type
# 0                              227
# Bakery                        1141
# Bakery, Beverage Shop           16
# Bakery, Cafe                    78
# Bakery, Dessert Parlor         147
#                               ...
# Sweet Shop                     468
# Sweet Shop, Dessert Parlor       1
# Sweet Shop, Quick Bites        178
# Takeaway                       120
# Takeaway, Delivery            2037
# Name: location, Length: 94, dtype: int64

# %% [markdown]
# **DATA CLEANING**

# %%
df['rate']=df['rate'].str.split('/').str[0]

# %%
df=df.replace('NEW',0)
df=df.replace('-',0)

# %%
df['rate']=df['rate'].astype(float)

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df.dtypes
# Out:
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                           float64
# votes                            int64
# phone                           object
# location                        object
# rest_type                       object
# dish_liked                      object
# cuisines                        object
# approx_cost(for two people)     object
# reviews_list                    object
# menu_item                       object
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %% [markdown]
# **converting cost to float**

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].str.replace(',','')

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].astype(float)

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df.dtypes
# Out:
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                           float64
# votes                            int64
# phone                           object
# location                        object
# rest_type                       object
# dish_liked                      object
# cuisines                        object
# approx_cost(for two people)    float64
# reviews_list                    object
# menu_item                       object
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %% [markdown]
# **CONVERT into catgorial**

# %%
cat_col=['online_order','book_table','listed_in(type)','location']

# %%
for col in cat_col:
 df[col]=df[col].astype('category')

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df.dtypes
# Out:
# address                          object
# name                             object
# online_order                   category
# book_table                     category
# rate                            float64
# votes                             int64
# phone                            object
# location                       category
# rest_type                        object
# dish_liked                       object
# cuisines                         object
# approx_cost(for two people)     float64
# reviews_list                     object
# menu_item                        object
# listed_in(type)                category
# listed_in(city)                  object
# dtype: object

# %% [markdown]
# **UNIVERINATE**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['rate'],bins=5,kde=True)
plt.title('Rating' )
# Out:
# Text(0.5, 1.0, 'Rating')

# %%
sns.displot(df['rate'],kde=True)

# %%
sns.histplot(df['approx_cost(for two people)'],bins=6,kde=True)
plt.title('COST')
# Out:
# Text(0.5, 1.0, 'COST')

# %%
sns.histplot(df['votes'],bins=1,kde=True)
plt.title('Votes')
# Out:
# Text(0.5, 1.0, 'Votes')

# %%
sns.countplot(x=df['listed_in(type)'])
plt.figure(figsize=(4, 10))

# %%
sns.countplot(x=df['online_order'])
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %% [markdown]
# **COST VS RESTAURANT TYPE**

# %%
sort=df.sort_values(
    by='approx_cost(for two people)',
    ascending=False
).head(8)

# %%
sns.boxplot(y=df['rate'],x=df['online_order'])
plt.xticks(rotation=90)
plt.title('rate vs onlinr orders')
# Out:
# Text(0.5, 1.0, 'rate vs onlinr orders')

# %%
sns.boxplot(y=df['rate'],x=df['book_table'])
plt.xticks(rotation=90)
plt.title('rate vs book table')
# Out:
# Text(0.5, 1.0, 'rate vs book table')

# %%
sns.boxplot(y=df['rate'],x=df['rest_type'])
plt.xticks(rotation=90)
plt.title('rate vs book table')
# Out:
# Text(0.5, 1.0, 'rate vs book table')

# %%
sort=df.sort_values(
    by='rate',
    ascending=False
).head(10)

# %%
sns.boxplot(y=sort['rate'],x=sort['location'])
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Bannerghatta Road'),
#   Text(1, 0, 'Electronic City'),
#   Text(2, 0, 'Sarjapur Road'),
#   Text(3, 0, 'JP Nagar'),
#   Text(4, 0, 'Indiranagar'),
#   Text(5, 0, 'Koramangala 1st Block')])

# %% [markdown]
# **OUTLIER**

# %%
sns.boxplot(df['approx_cost(for two people)'])
# Out:
# <Axes: ylabel='approx_cost(for two people)'>

# %%
corr=df[['approx_cost(for two people)','rate']].corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **NON GRAPHICAL ANNYASIS**

# %%
df['approx_cost(for two people)'].count()
# Out:
# np.int64(51371)

# %%
df['approx_cost(for two people)'].value_counts()
# Out:
# approx_cost(for two people)
# 300      7576
# 400      6562
# 500      4980
# 200      4857
# 600      3714
#          ...
# 469         1
# 60          1
# 560         1
# 3,700       1
# 5,000       1
# Name: count, Length: 70, dtype: int64

# %%
df['cuisines'].value_counts()
# Out:
# cuisines
# North Indian                                 2913
# North Indian, Chinese                        2385
# South Indian                                 1828
# Biryani                                       918
# Bakery, Desserts                              911
#                                              ...
# Chinese, Biryani, North Indian, Beverages       1
# Bengali, Oriya, South Indian                    1
# South Indian, Fast Food, Beverages              1
# Chinese, Cafe                                   1
# North Indian, Chinese, Arabian, Momos           1
# Name: count, Length: 2723, dtype: int64

# %%
df['online_order'].value_counts()
# Out:
# online_order
# Yes    30444
# No     21273
# Name: count, dtype: int64

# %%
df['book_table'].value_counts()
# Out:
# book_table
# No     45268
# Yes     6449
# Name: count, dtype: int64

# %%
df['location'].value_counts()
# Out:
# location
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# Yelahanka                   6
# West Bangalore              6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: count, Length: 93, dtype: int64

# %%
df['rest_type'].value_counts()
# Out:
# rest_type
# Quick Bites                   19132
# Casual Dining                 10330
# Cafe                           3732
# Delivery                       2604
# Dessert Parlor                 2263
#                               ...
# Dessert Parlor, Kiosk             2
# Dessert Parlor, Food Court        2
# Food Court, Beverage Shop         2
# Sweet Shop, Dessert Parlor        1
# Quick Bites, Kiosk                1
# Name: count, Length: 93, dtype: int64

# %% [markdown]
# **UNIQUE VALUE**

# %%
df['location'].nunique()
# Out:
# 93

# %%
df['cuisines'].nunique()
# Out:
# 2723

# %%
df['approx_cost(for two people)'].nunique()
# Out:
# 70

# %%
df=df['cuisines'].str.split(',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-747233130.py in <cell line: 0>()
# ----> 1 df=df['cuisines'].str.split(',')
#
# NameError: name 'df' is not defined

# %%
df=df.explode('cuisines')

# %%
df
# Out:
# 0          North Indian
# 1               Mughlai
# 2               Chinese
# 3               Chinese
# 4          North Indian
#               ...
# 126859      Finger Food
# 126860      Finger Food
# 126861      Finger Food
# 126862     North Indian
# 126863      Continental
# Name: cuisines, Length: 126864, dtype: object
